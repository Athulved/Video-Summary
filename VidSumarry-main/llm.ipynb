# %%
# !pip install transformers
# !pip install huggingfacehub
# !pip install torch
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement huggingfacehub (from versions: none)
# ERROR: No matching distribution found for huggingfacehub
# ...

# %%
# !pip install accelerate

# %%
import os
os.environ['HF_TOKEN']="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"
os.environ['HUGGINGFACEHUB_API_TOKEN']="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"

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline
import torch
from accelerate import disk_offload

model_id = "meta-llama/Meta-Llama-3-8B"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_id)

# Load model with disk_offload
model = AutoModelForCausalLM.from_pretrained(
    model_id, 
    torch_dtype=torch.bfloat16, 
    device_map="auto"
)

# Offload to disk
disk_offload(model, "offload")

# Create pipeline
generator = pipeline("text-generation", model=model, tokenizer=tokenizer)

print(generator("Hey, how are you doing today?", max_length=50))
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# Error while downloading from https://huggingface.co/meta-llama/Meta-Llama-3-8B/resolve/main/tokenizer.json: HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out.
# Trying to resume download...
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 tokenizer = AutoTokenizer.from_pretrained(model_id)
#      10 # Load model with disk_offload
# ---> 11 model = AutoModelForCausalLM.from_pretrained(
#      12     model_id,
#      13     torch_dtype=torch.bfloat16,
#      14     device_map="auto"
#      15 )
# ...
